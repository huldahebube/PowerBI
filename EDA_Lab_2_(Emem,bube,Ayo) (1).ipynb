# %% [markdown]
# # Lab Two: Data Cleaning

# %% [markdown]
# Data cleaning is the very first part of any data analysis and/or machine learning project. In this lab, you will be going over some of the common data issues and applying suitable fixes.

# %% [markdown]
# ##### Loading libraries needed and the data

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Explaining the data we will be using for this and the next few labs

# %% [markdown]
# In this example, we have 2 datasets. The datasets from two different hypothetical clinics, "Clinic1" and "Clinic2" which diagnose patients with a novel device that takes many measurements. The final goal is to see if they have a particular disease or not.
#
# Measurements taken from patients in the two clinics are presented in dataframes `Lab2_df1.csv` and we also have an inspection log, recorded in `Lab2_df2.csv` file for the devices used in "Clinic1" and "Clinic2" where many variables from the device are measured.
#
# Two of these variables, `'M1'` and `'M3'`, are believed to affect the readings taken from the patients. The `Lab2_df1` dataset is labelled with an actual diagnosis of whether the patient had the disease or not, and the goal is to predict the existence of the disease based on the measurements taken from the patients. Since the variables of the devices, measured in inspection, affects the measurements taken from patients in clinics, they should also be considered. Here are the data frames:

# %% [markdown]
# #### Note: Cells which have '[A]' represents the activity you have to do.

# %%
# loading the 'Lab2_df1.csv' csv data
df1 = pd.read_csv('Lab2_df1.csv')

# This makes it so we are able to see 100 rows when displaying the data
pd.set_option('display.max_rows', 100)

# %%
df1.head(20)
# Out:
#     Unnamed: 0       EDate                 Name  Gender  Age Mode  \
# 0            0   6/10/2011          Cody Watson    male   72    d
# 1            1   2/20/2011        Jonathan Duke    male    9    e
# 2            2   6/27/2011  Charlene Houseworth  female   59    f
# 3            3   9/22/2010        Gregory Curci    Male   23    g
# 4            4   6/10/2011          Cody Watson    male   72    d
# 5            5   7/21/2011        Linda Sawicki  female   17    g
# 6            6    5/6/2011          Ruth Morgan  female   19    _
# 7            7    7/5/2011         Shane Acosta    male    5    f
# 8            8  10/31/2010          Tania Fuoco  female   41    f
# 9            9    5/1/2011    Arla Czachorowski  female   36    f
# 10          10   8/22/2010        Sheila Thomas  female   41    _
# 11          11   1/24/2011       Jimmy Martinez    male   36    e
# 12          12    2/4/2011         Phillip Boyd    male    2    f
# 13          13    9/1/2010          John Lesser    male   76    f
# 14          14   6/16/2011     David Montgomery    male    4    f
# 15          15   6/19/2011         Anita Mcgrew  female   32    e
# 16          16   12/3/2010         Daniel Moore    male   10    e
# 17          17   4/11/2011         Holly Molina  female   43    d
# 18          18   4/26/2011     Heather Esquivel  female   15    _
# 19          19    2/1/2011    Frankie Mitchener    male   43    f
#
#               H           H1         M        DD    Result
# 0             _            _  5.058993  1.481877  Negative
# 1   104.0876332  105.0876332  6.531724  2.266884  Negative
# 2   102.9043152  103.9043152  6.273313  0.396333  Positive
# 3   152.6516553  153.6516553  7.333626  0.557534  Positive
# 4             _            _  5.058993  1.481877  Negative
# 5   67.23905431  68.23905431  3.642516  3.765706  Positive
# 6    54.0503086   55.0503086  7.193318 -0.173915         _
# 7   47.04644557  48.04644557  4.808863  6.446874  Negative
# 8             _            _  7.637614 -0.655884  Negative
# 9   109.6457241  110.6457241  7.006120  2.405082  Negative
# 10  108.2721498  109.2721498  7.369781  9.350549         _
# 11  106.4035386  107.4035386  4.329964 -2.105617  Positive
# 12  116.1817452  117.1817452  7.817222  5.456586  Negative
# 13            _            _  4.193204 -1.491731         _
# 14  146.3253216  147.3253216  4.370916 -5.119345  Positive
# 15  63.21008797  64.21008797  5.253893  5.946163  Negative
# 16  116.2191531  117.2191531  6.446360  2.041393  Negative
# 17            _            _  5.088270  4.504290  Positive
# 18  33.12832279  34.12832279  6.461212  0.213089  Negative
# 19   131.127339   132.127339  4.855666  2.858591  Positive

# %% [markdown]
# ## Looking at issues with the data

# %% [markdown]
# ##### Unique values of the `'Gender'` feature.

# %%
df1['Gender'].unique()
# Out:
# array(['male', 'female', 'Male', 'fmeale'], dtype=object)

# %% [markdown]
# ##### Unique values of the `'Mode'` feature.

# %%
df1['Mode'].unique()
# Out:
# array(['d', 'e', 'f', 'g', '_', 'F', 'h', 'a'], dtype=object)

# %% [markdown]
# ##### Observing the data types of each column.

# %%
df1.dtypes
# Out:
# Unnamed: 0      int64
# EDate          object
# Name           object
# Gender         object
# Age             int64
# Mode           object
# H              object
# H1             object
# M             float64
# DD            float64
# Result         object
# dtype: object

# %%
df1.shape
# Out:
# (61, 11)

# %% [markdown]
# # Lab Activity One: Guided Data Cleaning

# %% [markdown]
# ##### It is generally a good idea to make a copy of the master dataset for cleaning so you can always go back if ever needed.

# %%
df_clean = df1.copy()

# %% [markdown]
# ##### [A] Drop the `'Unnamed: 0'` column

# %%
df_clean = df_clean.drop(columns=['Unnamed: 0'])

# %% [markdown]
# ##### [A] Fix the data in the `'Gender'` column.
# > Hint: make it so there are 2 unique entries, `'male'` and `'female'`.

# %%
df_clean['Gender'].unique()
# Out:
# array(['male', 'female', 'Male', 'fmeale'], dtype=object)

# %%
df_clean['Gender'] = df_clean['Gender'].str.lower()
df_clean['Gender'] = df_clean['Gender'].replace('fmeale', 'female')

# %% [markdown]
# Check the 'Gender' column again

# %%
df_clean['Gender'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %% [markdown]
# ##### [A] Fix the data in the `'Mode'` column.
# > Hint: Check for lower and upper case entries

# %%
df_clean['Mode'].unique()
# Out:
# array(['d', 'e', 'f', 'g', '_', 'F', 'h', 'a'], dtype=object)

# %%
df_clean['Mode'] = df_clean['Mode'].str.lower()
df_clean['Mode'].unique()
# Out:
# array(['d', 'e', 'f', 'g', '_', 'h', 'a'], dtype=object)

# %% [markdown]
# ### Setting The Correct Data Type

# %% [markdown]
# ##### [A] Change the `'H'` column to numeric data `type(float64)` instead of `'object'`.

# %%
df_clean['H'] = pd.to_numeric(df_clean['H'], errors='coerce')
df_clean['H'].unique()
# Out:
# array([         nan, 104.0876332 , 102.9043152 , 152.6516553 ,
#         67.23905431,  54.0503086 ,  47.04644557, 109.6457241 ,
#        108.2721498 , 106.4035386 , 116.1817452 , 146.3253216 ,
#         63.21008797, 116.2191531 ,  33.12832279, 131.127339  ,
#        146.6806376 ,  76.43990201,  92.05440312, 124.294828  ,
#        106.7196982 , 129.7368202 ,  86.44666438, 119.601777  ,
#        123.201676  ,  91.65986797, 112.7280281 ,  72.41530029,
#        116.144212  , 110.5813683 ,  96.77082449,  92.18688263,
#        119.8767474 , 112.9196741 ,  69.87066139,  84.67450841,
#         71.96734654,  92.90387335,  85.91122925, 129.1457066 ,
#        118.8371796 , 120.960522  , 149.9719662 , 101.7176477 ,
#        104.1929329 , 109.8663068 , 100.3791042 ,  98.54798923,
#        120.6690182 ])

# %% [markdown]
# *Check* the 'H' column again

# %%
df_clean['H'].dtypes
# Out:
# dtype('float64')

# %% [markdown]
# ##### [A] Convert `'EDate'` column to `datetime` type.

# %%
df_clean['EDate'] = pd.to_datetime(df_clean['EDate'])

# %%
df_clean.dtypes
# Out:
# EDate     datetime64[ns]
# Name              object
# Gender            object
# Age                int64
# Mode              object
# H                float64
# H1                object
# M                float64
# DD               float64
# Result            object
# dtype: object

# %% [markdown]
# ##### Using the `gender_type` key we set the `'Gender'` column as categorical data.

# %%
gender_type = pd.CategoricalDtype(categories=["female", "male"])

df_clean["Gender"] = df_clean["Gender"].astype(gender_type)

# %%
df_clean.dtypes
# Out:
# EDate     datetime64[ns]
# Name              object
# Gender          category
# Age                int64
# Mode              object
# H                float64
# H1                object
# M                float64
# DD               float64
# Result            object
# dtype: object

# %% [markdown]
# ##### [A] Replicate how we changed the gender column to categorical but this time for the `'Mode'` column.

# %%
mode_type = pd.CategoricalDtype(categories=["f", "g", "d", "e","_","h","a"])
df_clean['Mode'] = df_clean['Mode'].astype(mode_type)

# %% [markdown]
# ##### [A] Again, change the `'Result'` column to categorical replicating above the example above.

# %%
result_type = pd.CategoricalDtype(categories=["positive", "negative"])
df_clean['Result'] = df_clean['Result'].astype(result_type)

# %% [markdown]
# ### Duplicate Entries
# - Duplicate entities in a dataset is not good to have as it  can use overfit and is redundant information

# %% [markdown]
# ##### [A] Check for duplicate entries and delete them

# %%
duplicate_rows = df_clean.duplicated()

# %%
display(duplicate_rows)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4      True
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32     True
# 33    False
# 34    False
# 35    False
# 36     True
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# 50    False
# 51    False
# 52    False
# 53    False
# 54    False
# 55    False
# 56    False
# 57    False
# 58    False
# 59    False
# 60    False
# dtype: bool

# %% [markdown]
# before using tilde operator
# True = Duplicated, False = not duplicated
#
# After using tilde operator:
# False = Duplicated, Trues = Not _ duplicated

# %%
df_clean = df_clean[~duplicate_rows]

# %%
df_clean
# Out:
#         EDate                  Name  Gender  Age Mode           H  \
# 0  2011-06-10           Cody Watson    male   72    d         NaN
# 1  2011-02-20         Jonathan Duke    male    9    e  104.087633
# 2  2011-06-27   Charlene Houseworth  female   59    f  102.904315
# 3  2010-09-22         Gregory Curci    male   23    g  152.651655
# 5  2011-07-21         Linda Sawicki  female   17    g   67.239054
# 6  2011-05-06           Ruth Morgan  female   19    _   54.050309
# 7  2011-07-05          Shane Acosta    male    5    f   47.046446
# 8  2010-10-31           Tania Fuoco  female   41    f         NaN
# 9  2011-05-01     Arla Czachorowski  female   36    f  109.645724
# 10 2010-08-22         Sheila Thomas  female   41    _  108.272150
# 11 2011-01-24        Jimmy Martinez    male   36    e  106.403539
# 12 2011-02-04          Phillip Boyd    male    2    f  116.181745
# 7   48.04644557  4.808863  6.446874    NaN
# 8             _  7.637614 -0.655884    NaN
# 9   110.6457241  7.006120  2.405082    NaN
# 10  109.2721498  7.369781  9.350549    NaN
# 11  107.4035386  4.329964 -2.105617    NaN
# 12  117.1817452  7.817222  5.456586    NaN
# 13            _  4.193204 -1.491731    NaN
# 14  147.3253216  4.370916 -5.119345    NaN
# 15  64.21008797  5.253893  5.946163    NaN
# 16  117.2191531  6.446360  2.041393    NaN
# 17            _  5.088270  4.504290    NaN
# 18  34.12832279  6.461212  0.213089    NaN
# 19   132.127339  4.855666  2.858591    NaN
# 20  147.6806376  5.767645  1.362450    NaN
# 21  77.43990201  6.853351  7.144657    NaN
# 22  93.05440312  5.823945  3.069055    NaN
# 23   125.294828  6.188929 -4.614200    NaN
# 24  107.7196982  6.085462 -8.263394    NaN
# 25  130.7368202  5.858931  2.689617    NaN
# 26  87.44666438  5.025699 -1.713491    NaN
# 27   120.601777  5.966730  3.440177    NaN
# 28   124.201676  4.843007  5.064505    NaN
# 29            _  6.725675 -1.294398    NaN
# 30            _  3.702969 -1.740168    NaN
# 31  92.65986797  6.397731  4.106246    NaN
# 33            _  5.507379 -2.492783    NaN
# 34  113.7280281  4.797970  2.266737    NaN
# 35  73.41530029  6.214333  2.746591    NaN
# 37   117.144212  3.897702 -0.877424    NaN
# 38  111.5813683  5.949869  2.007187    NaN
# 39  97.77082449  5.066335  3.500904    NaN
# 40  93.18688263  4.192012 -2.593210    NaN
# 41            _  6.686434  4.710838    NaN
# 42  120.8767474  5.720786 -2.959588    NaN
# 43  113.9196741  6.369615 -2.065630    NaN
# 44  70.87066139  5.600482 -2.195055    NaN
# 45  85.67450841  4.947849 -7.013755    NaN
# 46  72.96734654  6.730994 -1.491034    NaN
# 47  93.90387335  5.513919  4.808042    NaN
# 48  86.91122925  5.280809 -2.505498    NaN
# 49  130.1457066  5.557521 -1.655331    NaN
# 50  119.8371796  5.501253  4.932782    NaN
# 51   121.960522  5.554830  3.303376    NaN
# 52  150.9719662  4.714037 -2.236160    NaN
# 53            _  5.483929  1.528417    NaN
# 54  102.7176477  6.376439 -1.193141    NaN
# 55  105.1929329  5.759295  4.203775    NaN
# 56  110.8663068  4.137636  6.405663    NaN
# 57  101.3791042  6.295158 -2.297059    NaN
# 58            _  5.524661  3.867672    NaN
# 59  99.54798923  2.688670  1.897595    NaN
# 60  121.6690182  5.241279  1.911511    NaN

# %% [markdown]
# ##### [A] Once you delete a row in your dataset the index of that row is also deleted. Reset the index of the dataset so it in proper order.
# > Hint: use the `dataframe.reset_index` function and set the drop parameter to `True`.

# %%
df_clean = df_clean.reset_index(drop=True)
df_clean
# Out:
#         EDate                  Name  Gender  Age Mode           H  \
# 0  2011-06-10           Cody Watson    male   72    d         NaN
# 1  2011-02-20         Jonathan Duke    male    9    e  104.087633
# 2  2011-06-27   Charlene Houseworth  female   59    f  102.904315
# 3  2010-09-22         Gregory Curci    male   23    g  152.651655
# 4  2011-07-21         Linda Sawicki  female   17    g   67.239054
# 5  2011-05-06           Ruth Morgan  female   19    _   54.050309
# 57 2011-05-15         Joseph Beatty    male   33    f  120.669018
#
#              H1         M        DD Result
# 0             _  5.058993  1.481877    NaN
# 1   105.0876332  6.531724  2.266884    NaN
# 2   103.9043152  6.273313  0.396333    NaN
# 3   153.6516553  7.333626  0.557534    NaN
# 4   68.23905431  3.642516  3.765706    NaN
# 5    55.0503086  7.193318 -0.173915    NaN
# 6   48.04644557  4.808863  6.446874    NaN
# 7             _  7.637614 -0.655884    NaN
# 8   110.6457241  7.006120  2.405082    NaN
# 9   109.2721498  7.369781  9.350549    NaN
# 10  107.4035386  4.329964 -2.105617    NaN
# 11  117.1817452  7.817222  5.456586    NaN
# 12            _  4.193204 -1.491731    NaN
# 13  147.3253216  4.370916 -5.119345    NaN
# 14  64.21008797  5.253893  5.946163    NaN
# 15  117.2191531  6.446360  2.041393    NaN
# 16            _  5.088270  4.504290    NaN
# 17  34.12832279  6.461212  0.213089    NaN
# 18   132.127339  4.855666  2.858591    NaN
# 19  147.6806376  5.767645  1.362450    NaN
# 20  77.43990201  6.853351  7.144657    NaN
# 21  93.05440312  5.823945  3.069055    NaN
# 22   125.294828  6.188929 -4.614200    NaN
# 23  107.7196982  6.085462 -8.263394    NaN
# 24  130.7368202  5.858931  2.689617    NaN
# 25  87.44666438  5.025699 -1.713491    NaN
# 26   120.601777  5.966730  3.440177    NaN
# 27   124.201676  4.843007  5.064505    NaN
# 28            _  6.725675 -1.294398    NaN
# 29            _  3.702969 -1.740168    NaN
# 30  92.65986797  6.397731  4.106246    NaN
# 31            _  5.507379 -2.492783    NaN
# 32  113.7280281  4.797970  2.266737    NaN
# 33  73.41530029  6.214333  2.746591    NaN
# 34   117.144212  3.897702 -0.877424    NaN
# 35  111.5813683  5.949869  2.007187    NaN
# 36  97.77082449  5.066335  3.500904    NaN
# 37  93.18688263  4.192012 -2.593210    NaN
# 38            _  6.686434  4.710838    NaN
# 39  120.8767474  5.720786 -2.959588    NaN
# 40  113.9196741  6.369615 -2.065630    NaN
# 41  70.87066139  5.600482 -2.195055    NaN
# 42  85.67450841  4.947849 -7.013755    NaN
# 43  72.96734654  6.730994 -1.491034    NaN
# 44  93.90387335  5.513919  4.808042    NaN
# 45  86.91122925  5.280809 -2.505498    NaN
# 46  130.1457066  5.557521 -1.655331    NaN
# 47  119.8371796  5.501253  4.932782    NaN
# 48   121.960522  5.554830  3.303376    NaN
# 49  150.9719662  4.714037 -2.236160    NaN
# 50            _  5.483929  1.528417    NaN
# 51  102.7176477  6.376439 -1.193141    NaN
# 52  105.1929329  5.759295  4.203775    NaN
# 53  110.8663068  4.137636  6.405663    NaN
# 54  101.3791042  6.295158 -2.297059    NaN
# 55            _  5.524661  3.867672    NaN
# 56  99.54798923  2.688670  1.897595    NaN
# 57  121.6690182  5.241279  1.911511    NaN

# %% [markdown]
# ##### [A] Check the data types of your dataframe and print the shape of the dataframe.

# %%
#Check data type
df_clean.dtypes
# Out:
# EDate     datetime64[ns]
# Name              object
# Gender          category
# Age                int64
# Mode            category
# H                float64
# H1                object
# M                float64
# DD               float64
# Result          category
# dtype: object

# %%
#Show the size of dataframe
df_clean.shape
# Out:
# (58, 10)

# %% [markdown]
# # Lab Activity Two: Clean a Dataset Yourself

# %% [markdown]
# In this activity, you will need to clean the dataset yourself using the examples from the activity above. The `Lab2_df2.csv` is loaded and displayed for you.

# %%
#Read Lab2_df2.csv file

df2 = pd.read_csv('Lab2_df2.csv') # load the data
pd.set_option('display.max_rows', 100)# displays the max row upto 100
df2.head(10)
# Out:
#    Unnamed: 0 Inspection Date           M1        M2        M3        M4  \
# 0           0        9/4/2010  0.079600881  0.007344  0.542921  0.000074
# 1           1       9/27/2010            _  0.000204  9.613118  0.000042
# 2           2       10/6/2010            _  0.000928  4.298943  0.000041
# 3           3      10/21/2010  0.877617221  0.002254  9.240019  0.000182
# 4           4      11/26/2010            _  0.008547  6.659528  0.000022
# 5           5      11/29/2010  0.751824622  0.006172  7.023103  0.000016
# 6           6        1/4/2011    0.9279763  0.000833  5.473454  0.000124
# 7           7       1/28/2011  0.905113763  0.008793  7.223218  0.000209
# 8           8        2/3/2011  0.091880053  0.001529  2.745545  0.000024
# 9           9        2/4/2011            _  0.007507  4.472094  0.000035
#
#   Site Name
# 0   Clinic1
# 1   Clinic1
# 2   Clinic1
# 3   Clinic1
# 4   Clinic1
# 5   Clinic1
# 6   Clinic2
# 7   Clinic2
# 8   Clinic1
# 9   Clinic2

# %% [markdown]
# ##### [A] Figure out the issues with this dataset and apply the cleaning methods

# %%
df2.dtypes
# Out:
# Unnamed: 0           int64
# Inspection Date     object
# M1                  object
# M2                 float64
# M3                 float64
# M4                 float64
# Site Name           object
# dtype: object

# %% [markdown]
# Convert 'Inspection Date' column to datetime type.

# %%
df2['Inspection Date'] = pd.to_datetime(df2['Inspection Date'])

# %% [markdown]
# check the datatypes to confirm conversion

# %%
df2.dtypes
# Out:
# Unnamed: 0                  int64
# Inspection Date    datetime64[ns]
# M1                         object
# M2                        float64
# M3                        float64
# M4                        float64
# Site Name                  object
# dtype: object

# %%
#looking at the unique feature for the site name
df2['Site Name'].unique()
# Out:
# array(['Clinic1', 'Clinic2'], dtype=object)

# %%
#count the unique number for each site name
df2['Site Name'].value_counts()
# Out:
# Site Name
# Clinic1    13
# Clinic2     9
# Name: count, dtype: int64

# %%
#make a copy of the master dataset
df2_clean = df2.copy()

# %%
#drop the "UnNamed Collumn"
df2_clean = df2_clean.drop(columns=['Unnamed: 0'])

# %%
#check the dropped collumn is no longer displayed
df2_clean.head()
# Out:
#   Inspection Date        M1        M2        M3        M4 Site Name
# 0      2010-09-04  0.079601  0.007344  0.542921  0.000074   Clinic1
# 1      2010-09-27       NaN  0.000204  9.613118  0.000042   Clinic1
# 2      2010-10-06       NaN  0.000928  4.298943  0.000041   Clinic1
# 3      2010-10-21  0.877617  0.002254  9.240019  0.000182   Clinic1
# 4      2010-11-26       NaN  0.008547  6.659528  0.000022   Clinic1

# %%
#inspect the M1 collumn
df2_clean['M1'].dtype
# Out:
# dtype('float64')

# %%
#covert 'M1' Collumn to numeric data type (float) instead of object
df2_clean['M1'] = pd.to_numeric(df2['M1'], errors='coerce')

# %%
#check the 'M1' collumn again
df2_clean['M1'].dtypes
# Out:
# dtype('float64')

# %%
df2_clean.head()
# Out:
#   Inspection Date        M1        M2        M3        M4 Site Name
# 0      2010-09-04  0.079601  0.007344  0.542921  0.000074   Clinic1
# 1      2010-09-27       NaN  0.000204  9.613118  0.000042   Clinic1
# 2      2010-10-06       NaN  0.000928  4.298943  0.000041   Clinic1
# 3      2010-10-21  0.877617  0.002254  9.240019  0.000182   Clinic1
# 4      2010-11-26       NaN  0.008547  6.659528  0.000022   Clinic1

# %%
#Using the Clinic_type key we set the 'Clinic' column as categorical data.
clinic_type = pd.CategoricalDtype(categories=["Clinic1", "Clinic2"])
df2_clean['Site Name'] = df2_clean['Site Name'].astype(clinic_type)
df2_clean.dtypes
# Out:
# Inspection Date    datetime64[ns]
# M1                        float64
# M2                        float64
# M3                        float64
# M4                        float64
# Site Name                category
# dtype: object

# %%
duplicate_entries = df2_clean.duplicated()
display(duplicate_entries)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# dtype: bool

# %%
df2_clean = df2_clean[~duplicate_entries]
df2_clean
# Out:
#    Inspection Date        M1        M2         M3        M4 Site Name
# 0       2010-09-04  0.079601  0.007344   0.542921  0.000074   Clinic1
# 1       2010-09-27       NaN  0.000204   9.613118  0.000042   Clinic1
# 2       2010-10-06       NaN  0.000928   4.298943  0.000041   Clinic1
# 3       2010-10-21  0.877617  0.002254   9.240019  0.000182   Clinic1
# 4       2010-11-26       NaN  0.008547   6.659528  0.000022   Clinic1
# 5       2010-11-29  0.751825  0.006172   7.023103  0.000016   Clinic1
# 6       2011-01-04  0.927976  0.000833   5.473454  0.000124   Clinic2
# 7       2011-01-28  0.905114  0.008793   7.223218  0.000209   Clinic2
# 8       2011-02-03  0.091880  0.001529   2.745545  0.000024   Clinic1
# 9       2011-02-04       NaN  0.007507   4.472094  0.000035   Clinic2
# 10      2011-02-04  0.683924  0.008246   5.047370  0.000091   Clinic2
# 11      2011-02-17  0.603187  0.005955   5.686296  0.000179   Clinic1
# 12      2011-02-27  0.622961  0.000153   1.971804  0.000165   Clinic2
# 13      2011-03-10  0.510847  0.002235  11.652810  0.000121   Clinic1
# 14      2011-04-10       NaN  0.009962  10.822079  0.000084   Clinic2
# 15      2011-05-21  0.825806  0.008871  11.933157  0.000153   Clinic1
# 16      2011-05-21       NaN  0.009610   5.152056  0.000227   Clinic2
# 17      2011-05-30  0.498139  0.000391   7.036262  0.000145   Clinic2
# 18      2011-05-31  0.415378  0.007968   4.198182  0.000010   Clinic1
# 19      2011-06-10       NaN  0.001241   9.850274  0.000095   Clinic1
# 20      2011-07-17  0.638587  0.005587  10.053019  0.000028   Clinic2
# 21      2011-07-24  0.364427  0.000690   2.705533  0.000070   Clinic1

# %%
#Show the clean data
df2_clean.dtypes
# Out:
# Inspection Date    datetime64[ns]
# M1                        float64
# M2                        float64
# M3                        float64
# M4                        float64
# Site Name                category
# dtype: object

# %%
#size of the dataframe
df2_clean.shape
# Out:
# (22, 6)
